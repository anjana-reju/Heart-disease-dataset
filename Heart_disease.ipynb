# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# IMPORTING LIBRARIES FOR DATA PREPROCESSING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the csv file and giving d1 as file name
d1=pd.read_csv("Heart_disease.csv")
d1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# #There are 14 columns and 303 rows in which target is our output column

# %%
d1.shape
# Out:
# (303, 14)

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# #There are 303 entries for every column and there are no null values in our dataset.
# #All columns are integer datatype except oldpeak which is in float datatype

# %%
d1.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [raw]
# cp-chest pain type (1-typical angina,2-nontypical angina,3-non angynal pain,4-asymptomatic)
# trestbps-resting blood pressure
# chol -blood cholestrol level
# fbs- fasting blood sugar level
# restecg-resting ecg results(0-normal,1-wave abnormality,2-definite)
# thalach-maximum heart rate achieved
# exang-exercise induced angina
# oldpeak-ST depression induced by exercise relative to rest
# slope-slope of peak exercise(0-upsloping,1-flat,2-downslope)
# ca-no.of major vessels colored by flouroscopy
# thal-3-normal,6-fixed defect,7-reversable defect
# target-diagnosis of heart disease(0-<50% diameter narrowing, 1->50% diameter narrowing)

# %%
d1.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# #There are no null values in our dataset

# %%
#checking the number of unique values in each column
d1.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
#checking the maximum and minimum values in each column
for column in d1.columns:
    print(f"=======Column: {column}=======")
    print(f"Number of unique values: {d1[column].nunique()}")
    print(f"Max: {d1[column].max()}")
    print(f"Min: {d1[column].min()}")
# Out:
# =======Column: age=======
# Number of unique values: 41
# Max: 77
# Min: 29
# =======Column: sex=======
# Number of unique values: 2
# Max: 1
# Min: 0
# =======Column: cp=======
# Number of unique values: 4
# Max: 3
# Min: 0
# =======Column: trestbps=======
# Number of unique values: 49
# Max: 200
# Min: 94
# =======Column: chol=======
# Number of unique values: 152
# Max: 564
# Min: 126
# =======Column: fbs=======
# Number of unique values: 2
# Max: 1
# Min: 0
# =======Column: restecg=======
# Number of unique values: 3
# Max: 2
# Min: 0
# =======Column: thalach=======
# Number of unique values: 91
# Max: 202
# Min: 71
# =======Column: exang=======
# Number of unique values: 2
# Max: 1
# Min: 0
# =======Column: oldpeak=======
# Number of unique values: 40
# Max: 6.2
# Min: 0.0
# =======Column: slope=======
# Number of unique values: 3
# Max: 2
# Min: 0
# =======Column: ca=======
# Number of unique values: 5
# Max: 4
# Min: 0
# =======Column: thal=======
# Number of unique values: 4
# ...

# %% [raw]
# OBSERVATIONS
# 1)data is collected from age group 29 to 77
# 2)sex-1-male and 0-female
# 3)fbs(fasting blood sugar >120 mg/dl)-1-true,0-false
# 4)exang(exercise induced angina)-1-yes,0-no

# %%
#presence of null values can be checked in visual method using heatmap
sns.heatmap(d1.isnull())

# %% [markdown]
# #continous lines shows there are no null values

# %%
d1.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [raw]
# OBSERVATION
# 1)Description table gives an idea about total rows,minimum,maximum,mean,median,25%,75% and std deviation of each columns in our dataset.
# 2) There are 303 rows
# 3)mean is highest for chol and lowest for fbs
# 4)mean is greater than median for chol and oldpeak so they are right skewed datas
# 5)median is greater than mean for age,cp and thalach so they are left skewed datas
# 5)There is a large difference between 75% and maximum for trestbps,chol and thalach columns,this shows there are presence of outliers in this dataset.
# 6)Outliers must be treated to get a better analysis and a better accuracy

# %%
d1cor=d1.corr()
plt.figure(figsize=(10,12))
sns.heatmap(d1cor,cmap='Blues',annot=True,fmt='.0%')
plt.show()

# %% [raw]
# OBSERVATIONS
# 1)correlation map shows the correlation between each columns.
# 2)target is having a strong positive correlation with cp,thalach,and slope
# 3)target is having a strong negative correlation with  exang,oldpeak,ca and thal

# %% [markdown]
# This correlation heatmap can be expressed in matrix form also.It is displayed in descending order.columns with least correlation with target column are displayed at last.

# %%
corr_matrix=d1.corr()
print(corr_matrix["target"].sort_values(ascending=False))
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
collist=d1.columns.values
ncol=20
nrows=8

# %%
plt.figure(figsize=(ncol,2*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(d1[collist[i]],color='green',orient='v')

# %% [markdown]
# #The black dots in these boxplots represents outliers

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
sns.countplot(d1["target"])

# %% [markdown]
# #nearly 140 people have less than 50% diameter narrowing and above 160 peaple have greater than 50% diameter narrowing cases

# %%
sns.countplot(d1["cp"])

# %% [raw]
# 0-most of the people have typical angina
# 1-around 50 persons have atypical angina
# 2-nearly 90 people have non-anginal pain
# 3-only 25-30 persons are asymptomatic

# %%
sns.countplot(d1["fbs"])

# %% [raw]
# #1-only below 50 persons have fasting blood sugar greater than 120
# #0-most of the people(above 250)have fasting blood sugar less than 120

# %%
plt.subplots(figsize=(10,5))
sns.countplot(d1["age"])

# %% [raw]
# #data is collected from people ageing from 29 to 77
# #most of the people belong to age group 41 and 60
# #maximum number of people are from age group 58 and 59

# %%
sns.countplot(d1["exang"])

# %% [raw]
# #1-only less people have exercise induced angina
# 0- above 200 people donot have an exercise induced angina

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
f, ax=plt.subplots(figsize=(10,4))
sns.lineplot(x='target', y='age',hue='target',data=d1)

# %% [raw]
# #people ageing from 55 above is showing less than 50% diameter narrowing cases
# #people ageing from 50 to 55 is showing greater than 50% diameter narrowing cases

# %%
pd.crosstab(d1.target,d1.sex).plot(kind='bar',figsize=(8,5),color=['#1CA53B','#AA1111'])
plt.title('target and Gender')
plt.xlabel('target(0=<50%,1=>50%)')
plt.xticks(rotation=0)
plt.legend(['male','female'])
plt.ylabel('Gender')
plt.show()

# %% [markdown]
# #females are suffering high rate of heart diseases than men

# %%
pd.crosstab(d1.cp,d1.sex).plot(kind='bar',figsize=(8,5),color=['#1CA53B','#AA1111'])
plt.title('cp and Gender')
plt.xlabel('target(0=<50%,1=>50%)')
plt.xticks(rotation=0)
plt.legend(['male','female'])
plt.ylabel('Gender')
plt.show()

# %% [markdown]
# #here also we can clearly see that no.of females suffering from all types of chest pain are much more than men

# %%
f, ax=plt.subplots(figsize=(6,4))
sns.lineplot(x='trestbps', y='cp',hue='sex',data=d1)

# %% [markdown]
# #females have an high resting blood pressure and very high chest pain when compared to men

# %%
pd.crosstab(d1.ca,d1.age).plot(kind='bar',figsize=(8,5),color=['#1CA53B','#AA1111'])
plt.title('blood vessels and age')
plt.xlabel('ca')
plt.xticks(rotation=0)
plt.legend(['male','female'])
plt.ylabel('age')
plt.show()

# %%
d1["thal"].plot.box()

# %%
d1["ca"].plot.box()

# %%
d1["oldpeak"].plot.box()

# %%
d1["exang"].plot.box()

# %%
d1["cp"].plot.box()

# %%
d1["thalach"].plot.box()

# %%
d1.skew()
# Out:
# age        -0.202463
# sex        -0.791335
# cp          0.484732
# trestbps    0.713768
# chol        1.143401
# fbs         1.986652
# restecg     0.162522
# thalach    -0.537410
# exang       0.742532
# oldpeak     1.269720
# slope      -0.508316
# ca          1.310422
# thal       -0.476722
# target     -0.179821
# dtype: float64

# %% [raw]
# OBSERVATION
# columns with skewness values above and below 0.55 are skewed datas
# From these skew values we can see that many columns are highly skewed.

# %%
#plotting skewness graph
plt.figure(figsize=(20,30))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(d1[collist[i]])

# %%
#removing skewness using log method
for col in d1.columns:
    if d1.skew().loc[col]>0.55:
        d1[col]=np.log1p(d1[col])

# %%
#skewness graph after removal of skewness
plt.figure(figsize=(20,30))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(d1[collist[i]])

# %%
d1.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#Implementing Zscore to remove the presence of outliers
from scipy.stats import zscore
columns=['age','sex','cp','trestbps','chol','fbs','restecg','thalach',
       'exang','oldpeak','slope','ca','thal']
for i in range(len(columns)):
    d1[columns[i]]=zscore(d1[columns[i]])
    for j in range(len(d1[columns[i]])):
        if d1[columns[i]][j]>3 or d1[columns[i]][j]<-3:
            d1[columns[i]].replace(d1[columns[i]][j],d1[columns[i]].median(),inplace=True)
            d1[columns[i]]=np.cbrt((d1[columns[i]]))

# %%
#Assigning x and y values to train the data
x=d1[columns]
y=d1[["target"]]

# %%
#Checking the shape of assigned x and y
print(x.shape)
print(y.shape)
# Out:
# (303, 13)
# (303, 1)

# %%
#Implementing standard scaler to scale the values to a common scale
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[ 0.9521966 ,  0.68100522,  1.97312292, ..., -2.27457861,
#         -0.79278503, -1.26511714],
#        [-1.91531289,  0.68100522,  1.00257707, ..., -2.27457861,
#         -0.79278503, -0.73592163],
#        [-1.47415758, -1.46841752,  0.03203122, ...,  0.97635214,
#         -0.79278503, -0.73592163],
#        ...,
#        [ 1.50364073,  0.68100522, -0.93851463, ..., -0.64911323,
#          1.36019964,  1.25134139],
#        [ 0.29046364,  0.68100522, -0.93851463, ..., -0.64911323,
#          0.56559706,  1.25134139],
#        [ 0.29046364, -1.46841752,  0.03203122, ..., -0.64911323,
#          0.56559706, -0.73592163]])

# %% [markdown]
# # MODEL PREDICTION

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score,roc_curve,roc_auc_score,auc

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
dtc=  DecisionTreeClassifier()

max_score=0
for r_state in range(40,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.25)
   
    dtc.fit(x_train,y_train)
    y_pred=dtc.predict(x_test)
    acc_scr=accuracy_score(y_test,y_pred)
    if acc_scr>max_score:
        max_score=acc_scr
        final_r_state=r_state
print("max accuracy score corresponding to",final_r_state,"is",max_score)
# Out:
# max accuracy score corresponding to 73 is 0.8552631578947368

# %%
x_train,x_test,y_train,Yytest=train_test_split(x,y,test_size=.25,random_state=73)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (227, 13)
# (76, 13)
# (227, 1)
# (76, 1)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
predlr=lr.predict(x_test)
print("Accuracy score :",accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# Accuracy score : 0.5263157894736842
# [[14 15]
#  [21 26]]
#               precision    recall  f1-score   support
#
#            0       0.40      0.48      0.44        29
#            1       0.63      0.55      0.59        47
#
#     accuracy                           0.53        76
#    macro avg       0.52      0.52      0.51        76
# weighted avg       0.54      0.53      0.53        76

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
predgnb=gnb.predict(x_test)
print("Accuracy score :",accuracy_score(y_test,predgnb))
print(confusion_matrix(y_test,predgnb))
print(classification_report(y_test,predgnb))
# Out:
# Accuracy score : 0.4868421052631579
# [[13 16]
#  [23 24]]
#               precision    recall  f1-score   support
#
#            0       0.36      0.45      0.40        29
#            1       0.60      0.51      0.55        47
#
#     accuracy                           0.49        76
#    macro avg       0.48      0.48      0.48        76
# weighted avg       0.51      0.49      0.49        76

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print("Accuracy score :",accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# Accuracy score : 0.5131578947368421
# [[13 16]
#  [21 26]]
#               precision    recall  f1-score   support
#
#            0       0.38      0.45      0.41        29
#            1       0.62      0.55      0.58        47
#
#     accuracy                           0.51        76
#    macro avg       0.50      0.50      0.50        76
# weighted avg       0.53      0.51      0.52        76

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print("Accuracy score :",accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# Accuracy score : 0.5394736842105263
# [[12 17]
#  [18 29]]
#               precision    recall  f1-score   support
#
#            0       0.40      0.41      0.41        29
#            1       0.63      0.62      0.62        47
#
#     accuracy                           0.54        76
#    macro avg       0.52      0.52      0.52        76
# weighted avg       0.54      0.54      0.54        76

# %%
#AUC-ROC CURVE
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=lr.predict_proba(x_test)[:,1]
y_pred_prob
# Out:
# array([0.99695014, 0.93009475, 0.03212277, 0.18623662, 0.34942814,
#        0.02092971, 0.02009481, 0.8202685 , 0.08262394, 0.0091384 ,
#        0.22173182, 0.12254595, 0.88468156, 0.91871929, 0.91306892,
#        0.39270443, 0.11915415, 0.83754383, 0.42904713, 0.36559733,
#        0.04015797, 0.00598358, 0.1529308 , 0.57886083, 0.49660847,
#        0.88092662, 0.84976679, 0.49200881, 0.00918548, 0.01161956,
#        0.03439083, 0.00428829, 0.69203251, 0.14965589, 0.97096712,
#        0.42282737, 0.79926485, 0.86994537, 0.99129331, 0.99351557,
#        0.96755481, 0.01526539, 0.93687183, 0.88263164, 0.59669378,
#        0.9763404 , 0.97616684, 0.87941088, 0.8793085 , 0.99784875,
#        0.89338659, 0.67704241, 0.0109219 , 0.56772354, 0.22615411,
#        0.99325747, 0.89267684, 0.10423349, 0.04587769, 0.07212422,
#        0.99756587, 0.00531489, 0.98113637, 0.22710612, 0.99264796,
#        0.22155428, 0.10777673, 0.07449434, 0.98127775, 0.53296502,
# ...

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
fpr
# Out:
# array([0.        , 0.03448276, 0.03448276, 0.06896552, 0.06896552,
#        0.10344828, 0.10344828, 0.13793103, 0.13793103, 0.20689655,
#        0.20689655, 0.34482759, 0.34482759, 0.37931034, 0.37931034,
#        0.44827586, 0.44827586, 0.55172414, 0.55172414, 0.62068966,
#        0.62068966, 0.65517241, 0.65517241, 0.68965517, 0.68965517,
#        0.72413793, 0.72413793, 0.75862069, 0.75862069, 0.89655172,
#        0.89655172, 0.93103448, 0.93103448, 0.96551724, 0.96551724,
#        1.        , 1.        ])

# %%
tpr
# Out:
# array([0.        , 0.        , 0.10638298, 0.10638298, 0.14893617,
#        0.14893617, 0.23404255, 0.23404255, 0.25531915, 0.25531915,
#        0.31914894, 0.31914894, 0.36170213, 0.36170213, 0.46808511,
#        0.46808511, 0.55319149, 0.55319149, 0.57446809, 0.57446809,
#        0.59574468, 0.59574468, 0.65957447, 0.65957447, 0.72340426,
#        0.72340426, 0.76595745, 0.76595745, 0.78723404, 0.78723404,
#        0.80851064, 0.80851064, 0.89361702, 0.89361702, 0.91489362,
#        0.91489362, 1.        ])

# %%
thresholds
# Out:
# array([1.99784875, 0.99784875, 0.99264796, 0.99129331, 0.98113637,
#        0.98029478, 0.97096712, 0.96755481, 0.93687183, 0.91944953,
#        0.89338659, 0.88092662, 0.8793085 , 0.86994537, 0.8202685 ,
#        0.79926485, 0.57886083, 0.49660847, 0.49200881, 0.42282737,
#        0.39270443, 0.36559733, 0.22615411, 0.22173182, 0.1529308 ,
#        0.14965589, 0.11915415, 0.10777673, 0.10423349, 0.04587769,
#        0.04015797, 0.03439083, 0.01526539, 0.01161956, 0.0109219 ,
#        0.00918548, 0.00428829])

# %%
auc_score=roc_auc_score(y_test,lr.predict(x_test))
print(auc_score)
# Out:
# 0.5179750550256786

# %%
#using ensemble technique to boost our score
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=20,random_state=86)
rf.fit(x_train,y_train)
print('score:',rf.score(x_train,y_train))
predrf=rf.predict(x_test)
print('\n')
print("Accuracy score :",accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# score: 0.9955947136563876
#
#
# Accuracy score : 0.5526315789473685
# [[16 13]
#  [21 26]]
#               precision    recall  f1-score   support
#
#            0       0.43      0.55      0.48        29
#            1       0.67      0.55      0.60        47
#
#     accuracy                           0.55        76
#    macro avg       0.55      0.55      0.54        76
# weighted avg       0.58      0.55      0.56        76

# %%
#random forest classifier is giving a better result,so checking its cross val score
rf=RandomForestClassifier()
score=cross_val_score(rf,x,y,cv=5)
print("score:",score)
print("Mean score:",score.mean())
print("Standard deviation:",score.std())
# Out:
# score: [0.83606557 0.86885246 0.81967213 0.85       0.78333333]
# Mean score: 0.831584699453552
# Standard deviation: 0.02904545075500375

# %% [markdown]
# #saving random forest classifier as best model

# %%
import joblib
joblib.dump(rf,'rf_heart-disease.pkl')
# Out:
# ['rf_heart-disease.pkl']
